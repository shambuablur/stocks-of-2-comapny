# %%
pip install yfinance
# Out:
# ...
#   Created wheel for yfinance: filename=yfinance-0.1.54-py2.py3-none-any.whl size=22409 sha256=d5cdb9a86210e9bc4daaaa0b1029a03869da0665847ba019f9228cb342843e9b
#   Stored in directory: /root/.cache/pip/wheels/f9/e3/5b/ec24dd2984b12d61e0abf26289746c2436a0e7844f26f2515c
# Successfully built yfinance
# ...

# %%
import yfinance as yf
RELIANCE.NS = yf.download('RELIANCE.NS',start='2015-07-05', end='2020-08-15')
RELIANCE.NS
# Out:
# [*********************100%***********************]  1 of 1 completed
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#                    Open         High  ...    Adj Close    Volume
# Date                                  ...
# 2015-07-06   498.049988   509.450012  ...   484.411591   5594680
# 2015-07-07   505.500000   508.299988  ...   478.544586   5163694
# 2015-07-08   497.924988   504.350006  ...   475.372559   6944656
# 2015-07-09   498.000000   500.500000  ...   470.984222   7427064
# 2015-07-10   495.549988   502.000000  ...   477.852905   7365212
# ...                 ...          ...  ...          ...       ...
# 2020-05-05  1453.699951  1479.000000  ...  1460.650024  20528490
# 2020-05-06  1464.000000  1484.949951  ...  1460.750000  18510252
# ...

# %%
import yfinance as yf
WIPRO.NS=yf.download('WIPRO.NS',start='2015-07-05', end='2020-08-15')
WIPRO.NS
# Out:
# [*********************100%***********************]  1 of 1 completed
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#                   Open        High         Low       Close   Adj Close   Volume
# Date
# 2015-07-06  204.205994  206.906006  203.888000  206.268997  189.158783  1933820
# 2015-07-07  207.563004  210.863007  207.263000  207.675003  190.448135  2082559
# 2015-07-08  206.662994  209.531006  205.875000  207.281006  190.086838  2597991
# 2015-07-09  207.263000  208.669006  203.718994  204.337997  187.387955  1832215
# 2015-07-10  206.250000  207.899994  204.580994  205.744003  188.677322  2969737
# ...                ...         ...         ...         ...         ...      ...
# 2020-05-05  191.449997  194.000000  182.199997  184.199997  184.199997  6932389
# ...

# %%
import pandas as pd
data = [RELIANCE.NS['Close'],WIPRO.NS['Close']]
data = pd.DataFrame(data).transpose()
data = pd.DataFrame(data.values)
data = data.rename(columns={0:"RELIANCE",1 : "WIPRO" })
data
# Out:
#          RELIANCE       WIPRO
# 0      507.774994  206.268997
# 1      501.625000  207.675003
# 2      498.299988  207.281006
# 3      493.700012  204.337997
# 4      500.899994  205.744003
# ...           ...         ...
# 1185  1460.650024  184.199997
# 1186  1460.750000  187.050003
# 1187  1506.949951  184.100006
# 1188  1561.800049  184.000000
# 1189  1576.800049  184.699997
#
# [1190 rows x 2 columns]

# %%
import matplotlib.pyplot as grp
data.plot(figsize=(10, 7))
grp.legend()
grp.title("Adjusted Close Price (15/08/2020) of RELNCE AND WIPRO companies ", fontsize=16)
grp.ylabel('Price', fontsize=14)
grp.xlabel('Year', fontsize=14)
grp.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
grp.show()

# %%
df = data 
grp.matshow(df.corr())
grp.xticks(range(len(df.columns)), df.columns)
grp.yticks(range(len(df.columns)), df.columns)
grp.colorbar()
grp.show()

# %%
RELIANCE.NS['Volume'].plot(figsize=(16,8),label = "RELIANCE",title='Volume')
WIPRO.NS['Volume'].plot(label = "WIPRO")
grp.legend();

# %%
RELIANCE.NS['Total Traded'] = RELIANCE.NS['Open'] * RELIANCE.NS['Volume']
WIPRO.NS['Total Traded'] = WIPRO.NS['Open'] * WIPRO.NS['Volume']
RELIANCE.NS['Total Traded'].plot(figsize=(16,8),label = "RELIANCE",title='Total Money Traded')
WIPRO.NS['Total Traded'].plot(label = "WIPRO")
grp.legend()
grp.ylabel('Total Money Traded')
# Out:
# Text(0, 0.5, 'Total Money Traded')

# %%
RELIANCE.NS['returns'] = RELIANCE.NS['Close'].pct_change(1)
WIPRO.NS['returns'] = WIPRO.NS['Close'].pct_change(1)

# %%
fig = grp.figure(figsize=(10,5))
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
ax1.plot(RELIANCE.NS['returns'][-15:-5])
ax1.set_xlabel("Date")
ax1.set_ylabel("Percent")
ax1.set_title("RELNCE last month returns data")
grp.show()

# %%
fig = grp.figure(figsize=(10,5))
ax1 = fig.add_axes([0.1,0.1,0.8,0.8])
ax1.plot(WIPRO.NS['returns'][-15:-5])
ax1.set_xlabel("Date")
ax1.set_ylabel("Percent")
ax1.set_title("WIPRO last month returns data")
grp.show()

# %%
RELIANCE.NS['returns'].hist(bins=100)

# %%
WIPRO.NS['returns'].hist(bins=100)

# %%
RELIANCE.NS['returns'].hist(bins=50,label='RELNCE',figsize = (10,8), alpha= 0.5)
WIPRO.NS['returns'].hist(bins=50,label='WIPRO', alpha= 0.5)
grp.xlabel('Returns')
grp.legend();

# %%
RELIANCE.NS['daily_cumulative_return'] = ( 1 + RELIANCE.NS['returns'] ).cumprod()
WIPRO.NS['daily_cumulative_return'] = ( 1 + WIPRO.NS['returns'] ).cumprod()
RELIANCE.NS['daily_cumulative_return'].plot(label='RELIANCE',figsize = (16,8),title = 'Cumilative Return')
WIPRO.NS['daily_cumulative_return'].plot(label='WIPRO')
grp.legend();

# %%
"## RELIANCE"""

print ("RELIANCE.NS returns mean = ", RELIANCE.NS['returns'].mean(),"\n\n",
       "RELIANCE.NS returns mean * 250 = ",RELIANCE.NS['returns'].mean()*250,"\n\n",
       "RELIANCE.NS returns Standard Deviation = ",RELIANCE.NS['returns'].std(),"\n\n",
       "RELIANCE.NS returns Standard Deviation * 250 * 0.5 = ",RELIANCE.NS['returns'].std()*250**0.5)
# Out:
# RELIANCE.NS returns mean =  0.0011343038325618297
#
#  RELIANCE.NS returns mean * 250 =  0.28357595814045744
#
#  RELIANCE.NS returns Standard Deviation =  0.019073249971202137
#
#  RELIANCE.NS returns Standard Deviation * 250 * 0.5 =  0.3015745614536985

# %%
"## RELIANCE"""

print ("WIPRO.NS returns mean = ", WIPRO.NS['returns'].mean(),"\n\n",
       "WIPRO.NS returns mean * 250 = ",WIPRO.NS['returns'].mean()*250,"\n\n",
       "WIPRO.NS returns Standard Deviation = ",WIPRO.NS['returns'].std(),"\n\n",
       "WIPRO.NS returns Standard Deviation * 250 * 0.5 = ",WIPRO.NS['returns'].std()*250**0.5)
# Out:
# WIPRO.NS returns mean =  1.3876566915175624e-05
#
#  WIPRO.NS returns mean * 250 =  0.003469141728793906
#
#  WIPRO.NS returns Standard Deviation =  0.014612055722771997
#
#  WIPRO.NS returns Standard Deviation * 250 * 0.5 =  0.23103688690628704

# %%
"## Final Results"""

print(RELIANCE.NS['returns'].std()*250**0.5)
print(WIPRO.NS['returns'].std()*250**0.5)
# Out:
# 0.3015745614536985
# 0.23103688690628704

# %%
RELIANCE.NS['returns'].plot(figsize=(10,7),label = "RELNCE")
WIPRO.NS['returns'].plot(figsize=(10, 7),label="WIPRO").legend()
grp.title("Returns of Two companies ", fontsize=16)
grp.ylabel('Returns', fontsize=14)
grp.xlabel('Year', fontsize=14)
grp.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
grp.show()
